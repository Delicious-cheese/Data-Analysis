# %% [markdown]
# ### ploting and visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.arange(10)
plt.plot(data)

# %% [markdown]
# ### figures and subplots

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax2 = fig.add_subplot(2, 2, 2)

# %%
ax3 = fig.add_subplot(2, 2, 3)
# Out:
# /anaconda3/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--') #? cumsum() 的作用？ k-- 是对谁--

# %%
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
plt.close('all')

# %%
fig, axes = plt.subplots(2, 3)
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1230c2240>,
# ...
#       dtype=object)

# %% [markdown]
# ### colors markers and line styles

# %%
plt.figure()

# %%
from numpy.random import randn

# %%
plt.plot(randn(30).cumsum(), 'ko--')

# %%
plt.close('all')  # ? 关闭画布？

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')

# %%
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')

# %%
plt.legend(loc='best')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### ticks, labels and legends

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

# %%
ticks = ax.set_xticks([0, 250, 500, 750, 1000])

# %%
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                            rotation=30, fontsize='small')

# %%
ax.set_title('first matplotlib plot')
# Out:
# Text(0.5, 1, 'first matplotlib plot')

# %%
ax.set_xlabel('stages')
# Out:
# Text(0.5, 3.1999999999999993, 'stages')

# %%
ax

# %%
from numpy.random import randn
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')

# %%
ax.plot(randn(1000).cumsum(), 'k--', label='two')

# %%
ax.plot(randn(1000).cumsum(), 'k.', label='three')

# %%
ax.legend(loc='best')   # ? legend的作用， loc参数是干什么的

# %% [markdown]
# ### annotations and drawing on a subplot

# %%
from datetime import datetime

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot(1, 1, 1)

# %%
data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

# %%
spx.plot(ax=ax, style='k-')

# %%
crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

# %%
for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008-2009 financial crisis')

# %% [markdown]
# ### plotting with pandas and seaborn

# %%
plt.close('all')

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100 ,10)
                 )
df.plot()  # ? 这里的cumsum参数不加会报错， 参数的作用是什么

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))

# %%
data.plot.bar(ax=axes[0], color='k', alpha=0.7)  # 画的方式有 plt.plot data.plot

# %%
data.plot(ax=axes[1], color='k', alpha=0.7)

# %%
np.random.seed(12348)

# %%
df = pd.DataFrame(np.random.randn(6, 4), 
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus')
                 )
df
# Out:
# Genus         A         B         C         D
# one    1.309562 -1.647653 -0.076477 -1.562585
# two    1.656111 -1.847125 -0.589575  0.832264
# three -0.180365  0.998860  0.802854 -0.253226
# four  -0.934185 -0.092905 -1.027632 -0.182916
# five   0.563362 -0.006496 -0.517052  2.453182
# six    0.287594 -1.397959  0.203887 -2.213737

# %%
df.plot.bar() # bar属于什么类别的图

# %%
plt.figure() # 函数的作用是什么？

# %%
df.plot.barh(stacked=True, alpha=0.5) # 水平的英文单词

# %%
plt.close('all')

# %%
tips = pd.read_csv('examples/tips.csv')
party_counts = pd.crosstab(tips['day'], tips['size']) #? crosstab交叉tab
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts = party_counts.loc[:, 2:5]  # loc 的区间是前闭后闭

# %%
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
party_pcts = party_counts.div(party_counts.sum(1), axis=0) #? sum(1) 参数是什么作用
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_pcts.plot.bar()

# %%
plt.close('all') #? 什么时候采用到

# %%
import seaborn as sns

# %%
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069

# %%
sns.barplot(x='tip_pct', y='day', data=tips, orient='h') #data.bar() 和 sns.barplot 分别在什么场合使用

# %%
plt.close('all')

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h')

# %%
plt.close('all')

# %%
sns.set(style='whitegrid')

# %% [markdown]
# ### histograms and density plots

# %%
plt.figure()

# %%
tips['tip_pct'].plot.hist(bins=50)  # ? 表格

# %%
plt.figure()

# %%
tips['tip_pct'].plot.density()

# %%
plt.figure()

# %%
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(10, 2, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
values
# Out:
# 0       0.315042
# 1      -0.137200
# 2       0.036238
# 3       0.757814
# 4       1.544269
# 5      -1.728043
# 6       0.793393
# 7      -0.347674
# 8       0.352498
# 9       1.028299
# 10      1.196514
# 11     -0.123497
# 12     -1.332044
# 13     -0.247196
# 14      1.175993
# 15      1.675405
# 16      0.674191
# 17     -0.110653
# 18     -3.182668
# 19      0.465899
# 20     -0.440171
# 21      1.001197
# 22     -1.052050
# 23     -0.991769
# 24      0.356595
# 25     -0.368673
# 26      0.904145
# 27      1.166427
# 28     -1.525369
# 29     -0.291607
#          ...
# 370    11.411129
# 371     7.088867
# 372    11.629313
# 373    12.130122
# 374    10.297347
# 375     8.813654
# 376     8.122574
# 377     6.448449
# 378     9.760017
# 379     8.733958
# 380     8.198647
# 381     7.292360
# 382     9.902035
# 383    10.118851
# 384     8.662136
# 385    11.802302
# 386     8.683952
# 387     7.326766
# 388    10.582080
# 389    11.975785
# 390    13.370519
# ...

# %%
sns.distplot(values, bins=100, color='k')

# %% [markdown]
# ### scatter or point plots

# %%
macro = pd.read_csv('examples/macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]

# %%
trans_data = np.log(data).diff().dropna()
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
plt.figure()

# %%
sns.regplot('m1', 'unemp', data=trans_data)
plt.title('Changes in log %s versus log %s' % ('m1', 'unemp'))
# Out:
# Text(0.5, 1.0, 'Changes in log m1 versus log unemp')

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.2})

# %% [markdown]
# ### facet grids and categorical data

# %%
sns.factorplot(x='day', y='tip_pct', hue='time', col='smoker',
               kind='bar', data=tips[tips.tip_pct < 1])
# Out:
# /anaconda3/envs/kaggle/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day', y='tip_pct', row='time',
               col='smoker',
               kind='bar', data=tips[tips.tip_pct < 1])

# %%
sns.factorplot(x='tip_pct', y='day', kind='box',
               data=tips[tips.tip_pct < 0.5])
